# %% [markdown]
# 3.1 - Polarized Albums
# ---
# The purpose of this section is to create albums based on songs with the positive or negative polarities. That way, a user can identify which songs bring a more mellow vibe, or a positive vibe. In the case of MF Doom and his complex language, this can be difficult to do typically for those who have not heard his songs or understand his lyrics. The use of nltk's vader is meant to find the polarities of the songs, and present folders containing those of the same polarity. Overall, I think this is pretty cool! If I wanted to find songs of an artist that are more positive and wouldn't put me in a bad mindset, I would use this!
#
# [1] - Imports
# [2] - Show Song Size
# [3] - Song Polarities
# [4] - Polarity Count
# [5] - Add Polarities to Folder

# %%
# Import Block
import re
import nltk
import os
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Download NLTK resources in case you don't have it installed 
nltk.download('vader_lexicon')

# %%
# Open and read the file. Can be changed to include your own file!
# This block is meant to check that your songs are being saved correctly
with open("CompleteCorpus.txt", "r") as file:
    corpus_content = file.read()
# Split the content into songs based on the delimiter "===SONG==="
songs = corpus_content.split("===SONG===")
# Remove any empty strings resulting from the splitting process
songs = [song.strip() for song in songs if song.strip()]
print("Number of songs:", len(songs))
# Print out a few songs to verify
for i in range(3):  # Print the first 3 songs
    print("Song", i+1, ":")
    print(songs[i][:100])
    print("----------------------")
# Out:
# Number of songs: 140
# Song 1 :
# 520102.html
# [Dr. Doom:]
# My servants began to forge what was to become
# The most dreaded costume on th
# ----------------------
# Song 2 :
# absolutely.html
# Absolute power corrupts absolutely
# If they get the villain surrounded then (AHEM!)
#
#
# ----------------------
# Song 3 :
# accordion.html
# Living off borrowed time, the clock tick faster
# That'd be the hour they knock the sli
# ----------------------

# %%
# Create a SentimentIntensityAnalyzer object
sid = SentimentIntensityAnalyzer()
# Read the corpus file and split it into individual songs based on the delimiter
with open("CompleteCorpus.txt", "r") as file:
    corpus_content = file.read()
songs = corpus_content.split("===SONG===")

# Remove any empty strings resulting from the splitting process
songs = [song.strip() for song in songs if song.strip()]
songs_with_polarity = []

# Iterate through each song and determine its polarity
for song in songs:
    # Get the polarity scores for each song and append to the list
    polarity_scores = sid.polarity_scores(song)
    songs_with_polarity.append((song, polarity_scores['compound']))
# Print each song and its tuple
for i, song_tuple in enumerate(songs_with_polarity):
    print("Song", i+1, ":")
    print("Content:", song_tuple[0][:100])
    print("Polarity Score:", song_tuple[1])
    print("----------------------")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\bengl\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Song 1 :
# Content: 520102.html
# [Dr. Doom:]
# My servants began to forge what was to become
# The most dreaded costume on th
# Polarity Score: 0.8691
# ----------------------
# Song 2 :
# Content: absolutely.html
# Absolute power corrupts absolutely
# If they get the villain surrounded then (AHEM!)
#
#
# Polarity Score: -0.9889
# ----------------------
# Song 3 :
# Content: accordion.html
# Living off borrowed time, the clock tick faster
# That'd be the hour they knock the sli
# Polarity Score: 0.9859
# ----------------------
# Song 4 :
# Content: adeadmouse.html
# Even then I had the uneasy feeling it wasn't young Viktor Vaughn who would need my p
# Polarity Score: -0.9875
# ----------------------
# Song 5 :
# Content: allcaps.html
# So nasty that it's probably somewhat of a travesty having me
# Daily told the people "You
# Polarity Score: -0.9512
# ----------------------
# Song 6 :
# Content: americasmostblunted.html
# Come out to show them
# Like, open the bruise up and let some of the bruise b
# Polarity Score: 0.9645
# ----------------------
# Song 7 :
# Content: angelz.html
# [Ghostface Killah:]
# Yea, that's right
# It's not a Hardy Boy mystery neither
# This is real
# Polarity Score: -0.9842
# ----------------------
# Song 8 :
# Content: antimatter.html
# [Mr. Fantastik:]
# From Venus to Mars back to Earth
# Back to the HBO satellite
# It's sho
# Polarity Score: 0.874
# ----------------------
# Song 9 :
# Content: athf.html
# [Meatwad:]
# Danger Doom in the hizzy!
# Widdy widdy widdy widdy widdy widdy widdy we
# We need
# Polarity Score: -0.9538
# ----------------------
# Song 10 :
# Content: backend.html
# Dub it off your man, don't spend that ten bucks
# I did it for the advance, the back end
# Polarity Score: 0.8233
# ----------------------
# Song 11 :
# Content: backinthedaysskit.html
# [Mister Fantastic:]
# It was back in the days when I met a brilliant student na
# Polarity Score: -0.3003
# ----------------------
# Song 12 :
# Content: badabing.html
# Not a lot of bling
# When he do the thing, bada boom, bada bing
# From the womb to the tom
# Polarity Score: -0.9973
# ----------------------
# Song 13 :
# Content: ballskin.html
# The flow is towin, precision as a afro trim
# All big letters but it isn't no acronym
# Sm
# Polarity Score: -0.1278
# ----------------------
# Song 14 :
# Content: banished.html
# Villain got banished
# Refused out the U.S., he ain't even Spanish
# Oaxacado, sock with t
# Polarity Score: -0.9406
# ----------------------
# Song 15 :
# Content: basketcase.html
# [Harvey Birdman:]
# Ladies and gentlemen of the jury, we all lived through the 70's
# Th
# Polarity Score: 0.6954
# ----------------------
# Song 16 :
# Content: battyboyz.html
# Oh shoot, get a load of that fruit
# In thigh high boots, red tighty-whities and blue c
# Polarity Score: -0.9924
# ----------------------
# Song 17 :
# Content: beefrapp.html
# Beef rap
# Could lead to gettin teeth capped
# Or even a wreath for mom dukes on some grie
# Polarity Score: -0.9623
# ----------------------
# Song 18 :
# Content: benziebox.html
# [Cee-Lo:]
# His name's, DOOM
# They wonder just who is he
# But don't worry
# Believe me he'l
# Polarity Score: 0.9788
# ----------------------
# Song 19 :
# Content: bistro.html
# Ladies and gentlemen, welcome to the debut grand opening
# Of Madvillain Bistro Bed and Br
# Polarity Score: 0.9274
# ----------------------
# Song 20 :
# Content: bitethethong.html
# [MF Doom:]
# Dudes is doin' fashion shows
# JJ DOOM go pop, not so irrational
# You see
# Polarity Score: 0.9807
# ----------------------
# Song 21 :
# Content: bloodychain.html
# [MF Doom:]
# ...Had this one bitty, she gave good brain
# Used to come and see me in th
# Polarity Score: -0.9901
# ----------------------
# Song 22 :
# Content: borinconvo.html
# The supervillain get kicked out your country
# And said the Pledge of Allegiance six t
# Polarity Score: -0.9161
# ----------------------
# Song 23 :
# Content: bouttheshoes.html
# Third eye mascara running
# Into the truth
# Keep an ear pressed to the ground
# So you
# Polarity Score: 0.9983
# ----------------------
# Song 24 :
# Content: bumpysmessage.html
# [Bumpy Knuckles:]
# Yo what's up Doom, it's Bumpy Knuckles
# Just calling to say that
# Polarity Score: -0.6452
# ----------------------
# Song 25 :
# Content: caskets.html
# Young blood, he's smart and he's tough
# But he's got a lot to learn about survival
# And t
# Polarity Score: 0.9838
# ----------------------
# Song 26 :
# Content: cellz.html
# DOOM from the realm of Al-Qayyum. Smelly gel fume
# Separating cell womb to Mele Mel, boom!
# Polarity Score: -0.9737
# ----------------------
# Song 27 :
# Content: changethebeat.html
# A modern day marvel but terrible, better horrible
# When he grab the mic from son h
# Polarity Score: 0.8149
# ----------------------
# Song 28 :
# Content: comingforyou.html
# Uh, yeah, yeah
# Uh, yeah, yeah
# Uh, yeah, yeah
#
# I said Emperor Nehru, we're coming f
# Polarity Score: 0.9671
# ----------------------
# Song 29 :
# Content: crosshairs.html
# [MF Doom:]
# The fat is in the fire, a fryer made of chicken wire
# Gettin' sick and tir
# Polarity Score: -0.8569
# ----------------------
# Song 30 :
# Content: curls.html
# Villain get the money like curls
# They just tryin' to get a nut like squirrels in his mad
# Polarity Score: -0.9071
# ----------------------
# Song 31 :
# Content: darknesshbu.html
# Cruel world, all I'm seeing is darkness
# Cruel, cruel world, all I'm seeing is darkn
# Polarity Score: -0.998
# ----------------------
# Song 32 :
# Content: dawgfriendly.html
# Ayo D what the dealy? You know me
# Dropping all these beats to slap these cats sill
# Polarity Score: 0.964
# ----------------------
# Song 33 :
# Content: deadbent.html
# Goddamn it
# Super motherfucking villain goddamn it
# About to get these millions, stacks
# Polarity Score: -0.7679
# ----------------------
# Song 34 :
# Content: deepfriedfrenz.html
# Before we go any further
# Friends
#
# As you call 'em, they call you when they need
# Polarity Score: 0.9902
# ----------------------
# Song 35 :
# Content: disastrous.html
# [Bishop Nehru:]
# Welcome back, here's more of the rawness
# Flows gorgeous, and no this
# Polarity Score: 0.796
# ----------------------
# Song 36 :
# Content: doomareyouawakeskit.html
# [Principal:]
# Doom, are you awake?
#
# [Dr. Doom:]
# Yes, but what do you want?
#
#
# Polarity Score: -0.919
# ----------------------
# Song 37 :
# Content: doomsday.html
# [Pebbles the Invisible Girl:]
# When I was led to you
# I knew you were the one for me
# I s
# Polarity Score: -0.988
# ----------------------
# Song 38 :
# Content: doperskiller.html
# [MF Doom:]
# People came from miles around to hear Vik rock it
# He learned a few new
# Polarity Score: -0.9834
# ----------------------
# Song 39 :
# Content: dopeskill.html
# [MF Doom:]
# It's Vik
# Known to kick a no joke vocal
# And given a chance, yoke ya slow po
# Polarity Score: 0.825
# ----------------------
# Song 40 :
# Content: elchupanibre.html
# Adult Swim presents: Danger Doom (And what else?)
# Why did you buy this album?
# I do
# Polarity Score: -0.9823
# ----------------------
# Song 41 :
# Content: eye.html
# [Stacy Epps:]
# Give me a little bit, a little bit
# Just a little bit, or a lot
#
# Pieces of the
# Polarity Score: 0.9128
# ----------------------
# Song 42 :
# Content: fallbacktittyfat.html
# MC's fall back
# Cause Vik in your ear with the whole ball of wax
# Call or fax fo
# Polarity Score: -0.9081
# ----------------------
# Song 43 :
# Content: fancyclown.html
# I knew you was fucking around
# Playing all innocent and hoeing since the foundation
# D
# Polarity Score: 0.9443
# ----------------------
# Song 44 :
# Content: fastlane.html
# [Biolante/Kurious:]
# Only god is judge, never plea the case
# Always aware of the truth w
# Polarity Score: 0.9363
# ----------------------
# Song 45 :
# Content: fazers.html
# Follow the light. The light is your guide
# I am controller of Planet X (Three-three!)
# And
# Polarity Score: 0.9137
# ----------------------
# Song 46 :
# Content: figaro.html
# The rest is empty with no brain but the clever nerd
# The best emcee with no chain ya ever
# Polarity Score: -0.9749
# ----------------------
# Song 47 :
# Content: gasdrawls.html
# By the way, I re-up on bad dreams, bag up screams in fiftys
# Be up on mad schemes that
# Polarity Score: -0.9873
# ----------------------
# Song 48 :
# Content: gazzillionear.html
# Villain man never ran with krills in his hand and
# Won't stop rockin' til he clock
# Polarity Score: 0.9536
# ----------------------
# Song 49 :
# Content: gazzillionearthomyorkeremix.html
# Villain man never ran with krills in his hand and
# Won't stop rockin
# Polarity Score: -0.7353
# ----------------------
# Song 50 :
# Content: gmc.html
# Party people know the name, Vik with a "k"
# If it's all the same, if it ain't don't bother
# T
# Polarity Score: -0.9027
# ----------------------
# Song 51 :
# Content: gmo.html
# [MF Doom:]
# There they go, feminizing men again
# Then pretend they don't know when we know it
# Polarity Score: -0.9024
# ----------------------
# Song 52 :
# Content: gowiththeflow.html
# Big up all the Monsta Island massive
# And beware before I triple dare you like the
# Polarity Score: -0.9898
# ----------------------
# Song 53 :
# Content: greatday.html
# It never really mattered too much to me
# That I was just too damn old to emcee
# All that
# Polarity Score: 0.9704
# ----------------------
# Song 54 :
# Content: greatthings.html
# [Bishop Nehru:]
# Emperor Nehru
# I'm here with
# (What up, kid?)
# DOOM the Villain
# Peace,
# Polarity Score: 0.9922
# ----------------------
# Song 55 :
# Content: guinnesses.html
# Running desperately low on food, they were forced to turn back
#
# (Well it should
# I de
# Polarity Score: -0.995
# ----------------------
# Song 56 :
# Content: gumbo.html
# You gotta watch your gums on this
# But it's, it's very good, it's very healthy
#
# (Not perfe
# Polarity Score: 0.9533
# ----------------------
# Song 57 :
# Content: guvnor.html
# Catch a throatful
# From the fire vocaled
# Ash and molten glass like
# Eyjafjallajökull
# The v
# Polarity Score: 0.5409
# ----------------------
# Song 58 :
# Content: hardcorehustle.html
# Madvillain...
#
# Jump on the track with a hardcore hustle
# With a busload a niggas
# Polarity Score: -0.549
# ----------------------
# Song 59 :
# Content: herovsvillainepilogue.html
# "And that ended Doom's plans for world destruction!"
# "And how did you man
# Polarity Score: -0.9982
# ----------------------
# Song 60 :
# Content: hey.html
# Good evening, ladies and gentlemen
# (Hey!)
# I'd like to thank you all for joining us this eve
# Polarity Score: 0.9932
# ----------------------
# Song 61 :
# Content: hoecakes.html
# KEEP YA HOES IN CHECK! (..Super!)
# I got this girl and she wants me to duke Her
# I told
# Polarity Score: 0.9889
# ----------------------
# Song 62 :
# Content: intro.html
# [Man on Radio:]
# So if you, say
# Let's say you meditate with the OM chant
# It takes a radio
# Polarity Score: -0.8777
# ----------------------
# Song 63 :
# Content: iwonder.html
# [Hassan Chop:]
# That's right I got problems and personal issues
# Stories that'll make ya-
# Polarity Score: -0.9945
# ----------------------
# Song 64 :
# Content: konkarne.html
# Darker than the East river, larger than the Empire State
# Where the beasts to guard the
# Polarity Score: 0.7273
# ----------------------
# Song 65 :
# Content: konqueso.html
# ...Give it a sec for the pain to start
# This wreck right here it ain't for the faint of
# Polarity Score: -0.6633
# ----------------------
# Song 66 :
# Content: kookies.html
# One little evening alone home
# End up with carpal tunnel syndrome
# And here I am, known f
# Polarity Score: 0.9818
# ----------------------
# Song 67 :
# Content: krazyworld.html
# [Hook - Gigan:]
# Krazy world, get it where you fit in
# Choose how to roll the dough, t
# Polarity Score: -0.9751
# ----------------------
# Song 68 :
# Content: lactoseandlecithin.html
# "Hello, I'm Dean Stockton of Eastern State University in America, and I am p
# Polarity Score: -0.8895
# ----------------------
# Song 69 :
# Content: letmewatch.html
# [Viktor Vaughn:]
# Mm... My cousin's friend's friend wanna meet me
# Saw V on TV, said s
# Polarity Score: 0.9169
# ----------------------
# Song 70 :
# Content: lickupon.html
# Confirmation of your worst fears
# Ever since his first years had a thirst for beers
# Bac
# Polarity Score: -0.9801
# ----------------------
# Song 71 :
# Content: lightworks.html
# What is the magic
# That makes one's eyes
# Sparkle and gleam, light up the skies?
# The n
# Polarity Score: 0.952
# ----------------------
# Song 72 :
# Content: lockjaw.html
# "Where's the intruder?" "Looks like he went to the tower"
#
# [Trunks:]
# Before I rock raps
# Polarity Score: -0.2003
# ----------------------
# Song 73 :
# Content: meanthemost.html
# [Bishop Nehru:]
# To me you mean the most baby
# You already know (yeah, you already kn
# Polarity Score: 0.9962
# ----------------------
# Song 74 :
# Content: meatgrinder.html
# Tripping off the beat kinda, dripping off the meat grinder
# Heat niner, pimping, str
# Polarity Score: 0.1295
# ----------------------
# Song 75 :
# Content: microwavemayo.html
# Chain smokin beedies til his brain's broken completely
# Get back on his feet, work
# Polarity Score: -0.9939
# ----------------------
# Song 76 :
# Content: mincemeat.html
# The Villain ain't rhymin off bread alone
# Let him get some cognac, a mic and a headpho
# Polarity Score: -0.6594
# ----------------------
# Song 77 :
# Content: moderndaymugging.html
# He used to get straight A's
# Nowadays get way paid is the pet phrase
# Set the st
# Polarity Score: 0.875
# ----------------------
# Song 78 :
# Content: moneyfolder.html
# The villain took on many forms...
#
# Let he who is without sin cast the first stone
# A
# Polarity Score: -0.9852
# ----------------------
# Song 79 :
# Content: monsterzero.html
# [Planet X Soldier:]
# The monster again, Zero!
# [Controller of Planet X:]
# Monster Zero
# Polarity Score: 0.9217
# ----------------------
# Song 80 :
# Content: morerhymin.html
# More rhyming, pure diamond, tore hymen, poor timing
# Raw lining, Paul Simon touring..
# Polarity Score: -0.9871
# ----------------------
# Song 81 :
# Content: mrclean.html
# Study your history -
# Whoever don't? I pity-the-fool like Mr. T
# Knowledge: this degree,
# Polarity Score: -0.956
# ----------------------
# Song 82 :
# Content: neverdead.html
# [M. Sayyid:]
# Curt Strifer
# The loon goon with the tunes in his tomb
# Hotter than June
# S
# Polarity Score: 0.9618
# ----------------------
# Song 83 :
# Content: nextlevels.html
# [Lil' Sci:]
# 1,2 1,2 yes!
# Yo, it's King Ghidra, combined with the forces of nine ethe
# Polarity Score: 0.9799
# ----------------------
# Song 84 :
# Content: nonames.html
# [Marco:]
# Well, Debbie thinks this is all about her biological clock
# And I
#
# [Stormy:]
# Sh
# Polarity Score: 0.9738
# ----------------------
# Song 85 :
# Content: nosnakesalive.html
# [King Ghidra/King Geedorah:]
# ..Geedorah has arrived
# You guys could take five
# By t
# Polarity Score: -0.9905
# ----------------------
# Song 86 :
# Content: odetoroadrage.html
# ...Yolk em, leave 'em with his feet danglin
# Got his degree in stranglin and stree
# Polarity Score: 0.7832
# ----------------------
# Song 87 :
# Content: oldschool.html
# [Talib Kweli:]
# One two three, in the place to be!
# MF Doom, Talib Kweli, ah here we go
# Polarity Score: 0.9964
# ----------------------
# Song 88 :
# Content: om.html
# When we meditate, what is the word we use? “Om”
# I want you to try this, let's all try togeth
# Polarity Score: 0.9955
# ----------------------
# Song 89 :
# Content: onebeer.html
# I get no kick from champagne
# Mere alcohol doesn't thrill me at all
# So tell me why shoul
# Polarity Score: 0.9621
# ----------------------
# Song 90 :
# Content: onesmartnigger.html
# See, people are too hung up on the word itself instead of the intent
# It's the in
# Polarity Score: 0.7797
# ----------------------
# Song 91 :
# Content: openmicnitept1.html
# [Willie B:]
# Wow, wow, hey, yeah, alright, man, that was great. BYE! Get the fuck
# Polarity Score: -0.9942
# ----------------------
# Song 92 :
# Content: openmicnitept2.html
# I get my weed from the best sources
# I like it smooth not course like horse hoove
# Polarity Score: -0.3448
# ----------------------
# Song 93 :
# Content: operationgreenbacks.html
# M-O-N-E-Y
# Never did a thing for L-O-V-I-N
# Never understand what people's he
# Polarity Score: -0.9409
# ----------------------
# Song 94 :
# Content: operationlifesaverakaminttest.html
# The world is under attack at this very moment by the most powerfu
# Polarity Score: 0.9656
# ----------------------
# Song 95 :
# Content: perfecthair.html
# Perfect hair, to the second power of forever
# Ask him do he need it? Hells yeah, now
# Polarity Score: 0.6667
# ----------------------
# Song 96 :
# Content: pooputtplatter.html
# I tripped a lot out here in the woods lately
#
# This is a platter of, this makes a
# Polarity Score: -0.633
# ----------------------
# Song 97 :
# Content: popquizbonusextracreditremix.html
# [MF Doom:]
# You better have your pencils ready!
# Number two!
#
# [IZ-Re
# Polarity Score: 0.8522
# ----------------------
# Song 98 :
# Content: popsnot.html
# It lasts longer if you take a picture
# It's Viktor the slickster
# I pick her
# Sips Schlitz
# Polarity Score: -0.9154
# ----------------------
# Song 99 :
# Content: potholderz.html
# (Hot shit) (Aww shit)...
#
# [Count Bass D:]
# I strive to be humble, lest I stumble
# Neve
# Polarity Score: -0.899
# ----------------------
# Song 100 :
# Content: raedawn.html
# I could understand it
# V the beat bandit who bring heat for the mic
# Unhand it!
# Whoever g
# Polarity Score: -0.9052
# ----------------------
# Song 101 :
# Content: raid.html
# [MF Doom:]
# "-Life is too..."
# Two two one-two
#
# How DOOM hold heat then preach non-violence?
# Polarity Score: 0.2399
# ----------------------
# Song 102 :
# Content: rainbows.html
# You know, you best to watch out
# 'Til you, be fresh out of clout
# Rumors that he got a m
# Polarity Score: -0.9692
# ----------------------
# Song 103 :
# Content: rapambush.html
# So we're gonna stand on perimeter
# We did have some shots fired right down the street
# Polarity Score: -0.9081
# ----------------------
# Song 104 :
# Content: rapgame.html
# [MF Doom:]
# This is an editorial funded by rhymers
# Against phony gangsters
# And mainstrea
# Polarity Score: -0.9989
# ----------------------
# Song 105 :
# Content: rappsnitchknishes.html
# [Mr. Fantastik & MF Doom:]
# Yo
# (Yo)
# MF DOOM
# (Mr. Fantastik) Mr. Fantastik
# (The
# Polarity Score: -0.9934
# ----------------------
# Song 106 :
# Content: redgold.html
# I remember when, last past November when
# Clown kid got pounded in with the Timberlands
#
# Polarity Score: -0.994
# ----------------------
# Song 107 :
# Content: retardedfren.html
# An honest day's work for an honest day's pay
# Stay taking wages the anonymous way
# C
# Polarity Score: 0.9591
# ----------------------
# Song 108 :
# Content: rhinestonecowboy.html
# Hold the cold one like he hold a old gun
# Like he hold the microphone and stole
# Polarity Score: 0.8167
# ----------------------
# Song 109 :
# Content: rhymeslikedimes.html
# [MF Doom:]
# Yo, yo, yo, y'all can't stand right here
# In his right hand was your
# Polarity Score: 0.9982
# ----------------------
# Song 110 :
# Content: rhyminslang.html
# [MF Doom:]
# Coppin' pains at night
# I'd be better off going bar hoppin'
# Waitin' to fi
# Polarity Score: 0.8111
# ----------------------
# Song 111 :
# Content: saliva.html
# Great balls of fire
# Guess who just crawled out the muck or mire
# That could make you trus
# Polarity Score: 0.9725
# ----------------------
# Song 112 :
# Content: shadowsoftomorrow.html
# [Lord Quas:]
# Today is the shadow of tomorrow
# Today is the present future of y
# Polarity Score: 0.9488
# ----------------------
# Song 113 :
# Content: soalone.html
# [Bishop Nehru:]
# They calling me the newest teen prodigy now
# Sixteen with big dreams, th
# Polarity Score: -0.9823
# ----------------------
# Song 114 :
# Content: sofaking.html
# [BillyWitchDoctor.com:]
# Please, read from sheets
# I am
# [Aqua Teens + Carl:]
# I am
# [BWD:]
# Polarity Score: -0.994
# ----------------------
# Song 115 :
# Content: spacehos.html
# [Space Ghost:]
# I don't believe this!
# I get rid of those two evil maniacs who try to ru
# Polarity Score: -0.9326
# ----------------------
# Song 116 :
# Content: stilldope.html
# I'm still dope even if the bag ain't Coach
# Even if I don't smoke till the hydro roach
# Polarity Score: -0.9768
# ----------------------
# Song 117 :
# Content: stillkaps.html
# WILLIE ISZ in all caps like MF explain DOOM!
# Cops refuse like a thousand elephants in
# Polarity Score: -0.6607
# ----------------------
# Song 118 :
# Content: strangeways.html
# (They stay... Strange ways)
#
# Wreak havoc, beep beep it's mad traffic
# Sleek and lavi
# Polarity Score: -0.7707
# ----------------------
# Song 119 :
# Content: supervillainintro.html
# Looks like I hit the jackpot! (Supervillain!)
# That's the best part of all! I'
# Polarity Score: 0.6331
# ----------------------
# Song 120 :
# Content: supervillainz.html
# [Posdnuos/P-Pain:]
# What rhymes with shillin, villain
# What rhymes with shmillain,
# Polarity Score: -0.4609
# ----------------------
# Song 121 :
# Content: thankyah.html
# Villain!
#
# (Thank you) Thank ya...
# thankyah.html
# Polarity Score: -0.3382
# ----------------------
# Song 122 :
# Content: thatsthat.html
# Already woke, spared a joke, barely spoke, rarely smoke
# Stared at folks when properly
# Polarity Score: -0.9327
# ----------------------
# Song 123 :
# Content: thedrop.html
# "Victor, a stranger can see you"
#
# If I'm not working or putting work in
# I'm either whee
# Polarity Score: -0.3723
# ----------------------
# Song 124 :
# Content: thefinalhour.html
# "The final hour is approaching for the people of Earth, hear this!"
#
# She said "Exc
# Polarity Score: -0.8359
# ----------------------
# Song 125 :
# Content: thefineprint.html
# Render unto Geedorah what is Geedorah's
# Ten to one he sees ya through a beaker and
# Polarity Score: -0.9593
# ----------------------
# Song 126 :
# Content: thefinest.html
# [MF Doom:]
# As the life cycle goes on... goes on
# And you learn to hold on (hold on)
# To
# Polarity Score: -0.9979
# ----------------------
# Song 127 :
# Content: thehandsofdoomskit.html
# [Dr. Doom:]
# I'll have to go ahead with my experiment right now
# Lower the dom
# Polarity Score: 0.976
# ----------------------
# Song 128 :
# Content: theillestvillains.html
# As luck would have it, one of America's two most powerful villains of the nex
# Polarity Score: -0.96
# ----------------------
# Song 129 :
# Content: themask.html
# "Is it much, too much to ask
# Not to hide behind the mask"
#
# [MF Doom:]
# Head on straight,
# Polarity Score: -0.9608
# ----------------------
# Song 130 :
# Content: themic.html
# [Pebbles the Invisible Girl:]
# Feel the magnetism between us (The mic)
# Growing stronger a
# Polarity Score: 0.9652
# ----------------------
# Song 131 :
# Content: themysteryofdoomskit.html
# [Sue:]
# There's still DOOM, what of him?
#
# [Dr. Doom:]
# What of DOOM, my dear
# Polarity Score: 0.1012
# ----------------------
# Song 132 :
# Content: thetimewefaceddoomskit.html
# [Phade:]
# When this reporter babe get here, she gon' be on our tip, man.
#
# Polarity Score: -0.9887
# ----------------------
# Song 133 :
# Content: ticktick.html
# [Grimm:] You know when you're gonna come in?
# [DOOM:] Nobody will never ever, ever, rea
# Polarity Score: -0.9558
# ----------------------
# Song 134 :
# Content: vatsofurine.html
# [Ignignokt:] Behold y'all, the digital vats of urine
# [Err:] Drink up bitches! Taste
# Polarity Score: 0.8936
# ----------------------
# Song 135 :
# Content: vaudevillevillain.html
# V. Vaughn, the travelin' Vaudeville Villain
# Who don't give a flyin' fuck who
# Polarity Score: -0.9579
# ----------------------
# Song 136 :
# Content: vomitspit.html
# It's the beat, he hear it in his sleep sometimes
# Blare it in your jeep so your people
# Polarity Score: 0.5267
# ----------------------
# Song 137 :
# Content: washyourhands.html
# Uh, she got a cool body, damn she got a cool body
#
# What I'm a tell you what to do
# Polarity Score: -0.9887
# ----------------------
# Song 138 :
# Content: whoyouthinkiam.html
# [Megalon:]
# Who you think I am, but who you want me to be?
#
# [King Ceasar:]
# ...Whe
# Polarity Score: -0.9974
# ----------------------
# Song 139 :
# Content: winterblues.html
# Melanin on melanin
# Your dude need to recharge off your velvet skin
# Make 'em feel li
# Polarity Score: 0.9702
# ----------------------
# Song 140 :
# Content: yessir.html
# Live! In stereo
#
# [Raekwon:]
# Yessir! This what I wanna hear my nigga, yeah
# Yeah yeah
# You
# Polarity Score: -0.9573
# ----------------------

# %%
# This block is meant to associate the songs in the list
# based on their polarities. This is the check that the
# Songs are being placed into the correct albums
positive_songs = []
negative_songs = []

# Iterate through each song tuple
for song_tuple in songs_with_polarity:
    song_content, polarity_score = song_tuple
    
    # Check if the polarity score is positive or negative
    # Could also include neutral songs, but wasn't sure
    # about the need for a neutral folder
    if polarity_score > 0:
        positive_songs.append(song_content)
    elif polarity_score < 0:
        negative_songs.append(song_content)

# Print the number of positive and negative songs
print("Number of positive songs:", len(positive_songs))
print("Number of negative songs:", len(negative_songs))

# Show that the songs are in the correct categories
print("\nExample of positive songs:")
for song in positive_songs[:3]: 
    print(song[:100])  
print("\nExample of negative songs:")
for song in negative_songs[:3]:  
    print(song[:100])
# Out:
# Number of positive songs: 61
# Number of negative songs: 79
#
# Example of positive songs:
# 520102.html
# [Dr. Doom:]
# My servants began to forge what was to become
# The most dreaded costume on th
# accordion.html
# Living off borrowed time, the clock tick faster
# That'd be the hour they knock the sli
# americasmostblunted.html
# Come out to show them
# Like, open the bruise up and let some of the bruise b
#
# Example of negative songs:
# absolutely.html
# Absolute power corrupts absolutely
# If they get the villain surrounded then (AHEM!)
#
#
# adeadmouse.html
# Even then I had the uneasy feeling it wasn't young Viktor Vaughn who would need my p
# allcaps.html
# So nasty that it's probably somewhat of a travesty having me
# Daily told the people "You

# %%
# Create folders for positive and negative songs
positive_folder = "Positive_Songs"
negative_folder = "Negative_Songs"

# Create directories if they don't exist
os.makedirs(positive_folder, exist_ok=True)
os.makedirs(negative_folder, exist_ok=True)

# Write positive songs to files
for i, song_content in enumerate(positive_songs):
    with open(os.path.join(positive_folder, f"positive_song_{i+1}.txt"), "w") as file:
        file.write(song_content)

# Write negative songs to files
for i, song_content in enumerate(negative_songs):
    with open(os.path.join(negative_folder, f"negative_song_{i+1}.txt"), "w") as file:
        file.write(song_content)

print("Positive songs have been saved to the folder:", positive_folder)
print("Negative songs have been saved to the folder:", negative_folder)
# Out:
# Positive songs have been saved to the folder: Positive_Songs
# Negative songs have been saved to the folder: Negative_Songs

# %% [markdown]
# And that's it! You now have a list of positive and negative songs from a corpus of one of my favorite artists! This code can be modified to include your own songs, and the naming conventions can also be changed to incorporate better folder names. Thanks for checking this out!
