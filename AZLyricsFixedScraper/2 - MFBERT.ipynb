# %%
import numpy as np
import pandas as pd
import time
import torch
import transformers as ppb # pytorch transformers
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %%
from transformers import pipeline
filename = "1DOOM.txt"
#Function to read through the given filename 
def read_file(file):
    sentences = []
    #Strip through the sentences of the corpus, and append each to the sentence
    with open(file,mode ='r',encoding ="utf-8") as file:
        for line in file:
            line = line.strip()
            if line:
                sentences.append(line)
    return sentences
#Sentences will consist of the sentences of the read file at different indices
sentences = read_file(filename)
print(sentences)
# Out:
# ['File: 520102.html', '[Dr. Doom:]', 'My servants began to forge what was to become', 'The most dreaded costume on the face of the earth', 'The last thing to fit was the mask', 'Will it conform to my twisted features in comfort', '[MF Doom:]', 'He cleans his metal mask with gasoline, they after him', 'Last seen pulling chicks like a fiend pull a fast one', "Can't put shit past him", 'Got niggas on his own team mad enough to blast him', 'Retarded in real life, on the mic Rain Man', 'Stand close to his main man like a chain gang', 'Who give a fuck about who or they fancy crew', "That's no mystery that Hardy Boys do with Nancy Drew", 'Sorta with her drawers down quarter', 'The extorter bring slaughter like "Well I oughta"', 'I suggest you hand over the formula doula', 'A villain in your land, in his land a ruler', 'Hard hitting like puffing a woola with Lieutenant Uhura', "Every day feel like it's an off day with Ferris Bueller", 'Brother pull heat to prove they not sweet', 'No matter h
# ...

# %%
classifier = pipeline("sentiment-analysis",model = "bert-base-uncased")

result = classifier(sentences)
if result[0]['label'] == 'LABEL_2':
    sentiment_label = 'Positive'
else:
    sentiment_label = 'Negative'
print("Sentiment:",sentiment_label)
print("Score:",result[0]["score"])
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Sentiment: Negative
# Score: 0.6339725255966187

# %%
print(result)
# Out:
# [{'label': 'LABEL_0', 'score': 0.6339725255966187}, {'label': 'LABEL_0', 'score': 0.611129879951477}, {'label': 'LABEL_0', 'score': 0.6107324957847595}, {'label': 'LABEL_0', 'score': 0.6158210039138794}, {'label': 'LABEL_0', 'score': 0.5875654816627502}, {'label': 'LABEL_0', 'score': 0.6092897057533264}, {'label': 'LABEL_0', 'score': 0.5899972319602966}, {'label': 'LABEL_0', 'score': 0.6413079500198364}, {'label': 'LABEL_0', 'score': 0.6297059059143066}, {'label': 'LABEL_0', 'score': 0.6017517447471619}, {'label': 'LABEL_0', 'score': 0.6312694549560547}, {'label': 'LABEL_0', 'score': 0.6334806680679321}, {'label': 'LABEL_0', 'score': 0.6486440300941467}, {'label': 'LABEL_0', 'score': 0.6268100142478943}, {'label': 'LABEL_0', 'score': 0.6104753613471985}, {'label': 'LABEL_0', 'score': 0.5967037081718445}, {'label': 'LABEL_0', 'score': 0.573356032371521}, {'label': 'LABEL_0', 'score': 0.6076470613479614}, {'label': 'LABEL_0', 'score': 0.6350246071815491}, {'label': 'LABEL_0', 'score': 
# ...

# %%
print(classifier("Hella old"))
# Out:
# [{'label': 'LABEL_0', 'score': 0.6092815399169922}]

# %%
model_class, tokenizer_class, pretrained_weights = (ppb.DistilBertModel, ppb.DistilBertTokenizer, 'distilbert-base-uncased')
tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
model = model_class.from_pretrained(pretrained_weights)

# %%
tokenized = batch_1[0].apply((lambda x: tokenizer.encode(x, add_special_tokens=True)))
print(tokenized[10] == identified[10])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 tokenized = batch_1[0].apply((lambda x: tokenizer.encode(x, add_special_tokens=True)))
#       2 print(tokenized[10] == identified[10])
#
# AttributeError: 'str' object has no attribute 'apply'

# %%
import pandas as pd

batch_1 = sentences[:2000]
df_batch_1 = pd.DataFrame(batch_1, columns=['Sentences'])

# Split the first sentence into words and count occurrences
word_counts = df_batch_1['Sentences'][0].split()
word_counts = pd.Series(word_counts).value_counts()

texts = df_batch_1['Sentences'].tolist()
identified = [tokenizer.encode(x, add_special_tokens=True) for x in texts]
print(identified[0])
# Out:
# [101, 5371, 1024, 19611, 10790, 2475, 1012, 16129, 102]

# %%
tokenized = batch_1[0].apply((lambda x: tokenizer.encode(x, add_special_tokens=True)))
print(tokenized[10] == identified[10])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 tokenized = batch_1[0].apply((lambda x: tokenizer.encode(x, add_special_tokens=True)))
#       2 print(tokenized[10] == identified[10])
#
# AttributeError: 'str' object has no attribute 'apply'
